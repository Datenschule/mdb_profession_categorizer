# %% [markdown]
# # Dictionaries for categorizing educational background of MdBs

# %% [markdown]
# This notebook contains two dictionaries for categorizing the educational background of Members of the german parliament

# %%
#Categories Narrow
profession_narrow = {'Autor/in':
                         ['Autor','Autorin'],
                     'Agraringenieur/in':
                         ['Selbstständiger Land- und Forstwirt','Selbstständiger Landwirt','Agraringenieurin','Diplom-Agraringenieur','Diplomagraringenieur','Meliorationsingenieurin','Diplom-Meliorationsingenieurin'],
                     'Angestellte/r':
                         ['Angestellter'],
                     'Apotheker/in':
                         ['Apotheker'],
                     'Architekt/in':
                         ['Architekt','selbstständige Architektin'],
                     'Ärzt/in':
                         ['Arzt','Ärztin'],
                     'Außendienstmitarbeiter/in':
                         ['Aussendienstmitarbeiter'],
                     'Bäcker/in':
                         ['Bäcker','Bäckerin'],
                     'Bankfachwirt/In':  
                         ['Bankfachwirtin','Bankkauffrau',
                          'Bankkaufmann','Sparkassenbetriebswirt','Bankfachwirt'],
                     'Betriebswirt/in':
                         ['Diplom-Betriebswirt (BA)',
                          'Diplom-Betriebswirt (FH)',
                          'Betriebswirtin',
                          'Betriebswirt',
                          'Betriebswirt (VWA)',
                          'Diplom-Betriebswirt',
                          'Diplom-Betriebswirtin (FH)',
                          'Diplom-Betriebswirtin',
                          'Diplomökon. des Gaststätten- und Hotelwesens',
                          'Kreisrat; Bankkaufmann; Diplom-Betriebswirt (FH)'],
                     
                     'Bauingenieur/in':
                         ['Bauingenieurin','Bauingenieur'],
                     'Baustofftechnologe/in':
                         ['Baustofftechnologin'],
              'Bauzeichner/in' :['Bauzeichner'],
              'Beamte/r':['Beamter'],
              'Bergmechaniker/in':
              ['Bergmechaniker','Bergmann','Baufrau'],
              'Bundestagsabgeordnete/r':['Bundestagsabgeordneter','MdB'],
              'Soldat': 
              ['Berufssoldat','Soldat','Soldatin'],
              'Lehrer/in':
              ['Lehramtstudium (Deutsch','Lehramtstudium (Deutsch, Geschichte, Gemeinschaftskunde)','Berufsschullehrer','Lehramtsstudium','Gymnasiallehrer','Gymnasiallehrer für Mathematik und Gemeinschaftskunde','Hauptschullehrerin','Lehramt (Deutsch/Geschichte)','Lehrer (in Pension)',
               'Lehrer (Sekundarstufe II/I)','Lehrer','Lehrerin','Oberstudienrat','Schulleiter','Sonderschullehrerin','Stellvertretender Schulleiter','Volkshochschulangestellter','Dipl.-Lehrer Biologie/Chemie',
                'Dipl.-Lehrer','Diplomlehrerin für Kunsterziehung und Geschichte',
                'Diplomlehrerin','Diplomsportlehrer','Diplom-Religionspädagogin','(Deutsch','Deutsch','Geschichte','Gemeinschaftskunde)'],
              'Jurist/In':
              ['Völkerrechtlerin','Richter am Amtsgericht a. D.','Richterin am Amtsgericht a. D.','Richter/in','Jurist','Jura','Juristin','Wirtschaftsjurist', 'Verwaltungsjuristin','Jurist (Dr. jur.)','Jurist und Diplom-Kaufmann','Jurist und Notar',
               'Rechtsanwalt und Fachanwalt für Steuerrecht','Rechtsanwalt und Notar','Rechtsanwalt','Rechtsanwältin','Fachanwalt für Arbeitsrecht','Volljurist','Diplom-Jurist',
                'Diplom-Juristin','Studium der Rechtswissenschaft'], 
              'Ärzt/in': 
              ['Arzt','Ärztin'],
              'Baufacharbeiter':
              ['Baufacharbeiter'],
              'Betriebswirt/in':['Betriebswirt (M. A.)','Betriebswirt','Betriebswirtin','Dipl.-Betriebswirt (FH)'],
              'Bundesminister/in':[' Bundesminister der Verteidigung a.D.','Bundesminister des Innern'],
              'Bundestagsabgeordnete/r':['Bundestagsabgeordneter'],
              'Bürgermeister/in':
              [ 'Bürgermeister','Bürgermeister a.D.','Bürgermeister a. D.','Bürgermeisterin a.D.','Ortsbürgermeister','Bürgermeister a. D.'],
              'Bürokaufmann/kauffrau':[' Bürokaufmann','Bürokauffrau'],
              'Gesellsch. Studium':
              ['Bachelor of Arts (Geschichte und Spanisch)',
               'der Soziologie und der Geschichte (M.A.).',
               'des Öffentlichen Rechts und der Literaturwissenschaften (M.A.)',
               'des Öffentlichen Rechts und der Philosophie (M.A.)'],
              'Projektmanager/in':
              ['Projektmanager Soziales'],
              'Baustofftechnologin':
              ['Baustofftechnologin'],
              'Bildungsberater':['Bildungsberater'],
              'Biologe/in':['Biologe','Biotechnologin','Diplom-Biologe'],
              'Buchhändler/in':['Buchhändlerin'],
              'Büroleitung':['Büroleitung'],
              'Chemiker/in':
              ['Chemiefacharbeiterin','Chemielaborant','Chemielaborantin','Dipl.-Chemikerin','Diplom Chemie-Ingenieur','Diplom-Chemiker',
                'Diplom-Chemikerin'],
              'Controller/in':['Controller'],
              'Damenschneidermeisterin':['Damenschneidermeisterin'],
              'Diakon/in':['Diakonin'],

              'Dozent/in':['Dozentin'],
              'Dramaturge/in':['Dramaturgin'],
              'Edelsteingutachter/in':['Edelsteingutachterin'],
              'Einzelhandelskauffrau':['Einzelhandelskauffrau','Kauffrau im Einzelhandel','Speditionskauffrau - derzeit kfm. Koordinatorin'],
              'Eisenbahnfacharbeiterin':['Eisenbahnfacharbeiterin'],
              'Elektrohandwerksmeister':['Elektrohandwerksmeister','Diplomelektroingenieur'],
              'Elektrohauer/in':['Elektrohauer'],
                     'Ernährungswissenschaftler/in':['Oecotrophologin','Diplom-Oecotrophologin'],
              'Elektroinstallateur/in':
              ['Elektroinstallateur',
               'Elektromeister in der Energiewirtschaft',
               'Energieanlagenelektroniker','Starkstromelektriker','Elektro-Techniker'],
              'Erzieher':['Erzieher','Erzieherin', 'Fachlehrerin'],
              'Examinierte Gesundheits- und Krankenpflegerin' : 
                ['Examinierte Gesundheits- und Krankenpflegerin'],
              'Kieferorthopäde/in':['Fachzahnarzt für Kierferorthopädie'],
              'Finanzwirt/in':['Finanzwirtin','Diplom-Finanzwirt','Diplom Finanzwirt (FH) - Angestellte'],
              'Journalist/in':
                     ['Freier Journalist','Journalist','Journalistin',
                      'Freiberufliche Redakteurin',
                      'Redakteur','Redakteurin','Redaktionsdirektor'],
                'Informatiker*in':['Freiberuflicher Gutachter und Entwickler (Dipl.-Biologe)','Informatikerin','Programmiererin','staatl. gepr. Informatikerin','Dipl.-Informatikerin (FH)','Diplom-Informatiker'],
              'Fremdsprachensekretär/in':['Fremdsprachensekretärin'],
              'Funkmechaniker/in':
                     ['Funkmechaniker'],
              'Gesellschafter/in':
                     ['Geschäftsführender Gesellschafter','Gesellschafter'],
              'Generalsekretär':
                     ['Generalsekretär','Generalsekretärin des Cusanuswerks'],
              'Geschäftsführer/in':
                     ['Geschäftsführer','Geschäftsführer','Geschäftsführerin','Landesgeschäftsführer','Geschäftsbereichsleiter'],
              'Politikberater/in':
                     ['gewerkschaftlicher Politikberater','Politikberater','Politikberaterin'],
            'Gewerkschafter/in':
                     ['Gewerkschaftssekretär','Gewerkschaftssekretärin'],
            'Glasermeister/in':
                     ['Glasermeister','Glasermeisterin'],
            'Goldschmied/in':['Goldschmiedin'],
            'Groß- und Außenhandelskaufmann':['Selbständiger Kaufmann','Großhandelskaufmann', 'Groß- und Außenhandelskaufmann','Baukaufmann'],
            'Sozialpädagoge/in':
                     ['Sozialpädagoge','Staatl. geprüfte und anerkannte Erzieherin','Diplom-Sozialpädagoge (FH)',
                    'Diplom-Sozialpädagoge','Diplom-Sozialpädagogin (FH)','Diplom-Sozialpädagogin','Diplom-Pädagogin','Diplom Sozialpädagoge/Sozialarbeiter','Diplom-Sozialarbeiterin','Dipl. -Sozialpädagogin (FH) / Angestellte','Studium der Erziehungswissenschaften'],
            'Hausfrau/mann':
                     ['Hausfrau','Hausmann','Meisterin der Ländlichen Hauswirtschaft'],
            'Hauswirtschaftsleiterin (Hwl)':
                     ['Hauswirtschaftsleiterin (Hwl)'],
            'Handelsfachwirt/in':
                     ['Handelsfachwirtin','Handelsfachwirt'],
            'Historiker/in':
                     ['Historiker','Historikerin'],
            'Parlamentarische Referent/in':['(Parl. Referentin)','Referentin Landesministerium NRW'],
            'sozialpolitischer Vorstand':['sozialpolitischer Vorstand'],
            'Hochschulagraringenieur/in':['Hochschulagraringenieur'],
            'Student/in':['Hochschulstudium Politikwissenschaften, Jura, Soziolgie, Geschichte'],
            'Professor/in':['Hochschulprofessor FHÖV, Münster'],
            'Immobilienmakler/in':['Immobilienmakler'],
            'Industriekauffrau/mann':['Industriekauffrau','Industriekaufmann','Speditionskauffrau - derzeit kfm. Koordinatorin'],
            'Personalfachkaufmann':['Personalfachkaufmann'],
            'Industriemechaniker':['Industriemechaniker'],
            'Kauffrau/mann':
                ['Diplom-Kauffrau','Diplom-Kaufmann','Dipl-Kfm.',
                 'Diplomkaufmann','Diplom Kaufmann','Kauffrau','Kaufmann im Groß- und Außenhandel','Kaufmann','Kaufmännischer Angestellter','Keramikmalerin'],
             'Kfz-Mechaniker':['Kfz-Mechaniker'],
             'Kinderpflegerin':['Kinderpflegerin'], 
             'Klassischer Philologe':['Klassischer Philologe'],
             'Kommunikationswissenschaftler/in':['Kommunikationswissenschaftlerin','Kommunikationswissenschaftlerin M.A.'],
             'Konditor/in':['Konditor'],
             'Krankenschwester/Krankenpfleger':['Krankenschwester','Krankenpfleger'],
             'Kreisrat':['Kreisrat','Kreisrätin'],
             'Kriminalbeamte/r':['Kriminalbeamter','Kriminalbeamte'],
             'Kulturreferent/in':['Kulturreferent'],
             'Kulturwissenschaftler/in':
                ['Kulturwissenschaftler','Kulturwissenschaftlerin','Kulturwissenschaftlerin (M.A.)'],
             'Kunstgeschichte und Germanistik':
                ['Kunstgeschichte und Germanistik','Kunstwissenschaftlerin'],
             'Geiger/in':
                ['Geigerin'],
             'Verwaltungswirt/in':
                ['Diplomverwaltungswirtin','Dipl.-Verwaltungswirt (FH)',
                 'Diplomverwaltungswirt (FH) und Bürgermeister',
                'Diplomverwaltungswirt','Diplomverwaltungswirtin'],
             'Islamwissenschaftler/in':
                ['Islamwissenschaftlerin'],
             'Ingenieur/in':['Dipl.-Ing. (FH)','Diplom-Ingenieur (FH)',
                'Diplom-Ingenieur für Informationsverarbeitung',
                'Diplom-Ingenieur für Textiltechnologie',
                'Diplom-Ingenieur',
                'Ingenieurin',
                'Diplom-Ingenieurin (FH) FB Architektur',
                'Diplom-Ingenieurin (FH)',
                'Diplom-Ingenieurin','Diplomingenieur',
                'Diplom-Wirtschaftsingenieur (FH)','Dipl.-Wirtschaftsingenieur'],
             'Volkswirt/in':
                ['Volkswirtin','Volkswirt','Volkswirtin','Dipl.-Volkswirt (Uni)',
                'Dipl.-Volkswirt','Diplom-Volkswirt und Diplom-Sozialökonom','Diplom-Sozialökonomin',
                'Diplom-Volkswirt',
                'Diplom-Volkswirtin','Dipl. Volkswirtin','Studentin der Volkswirtschaftslehre',
               'Studium der Volkswirtschaftslehre','Diplom-Ökonom','Diplomökonomin'],
             'Vorsitzender':
                ['Landesvorsitzender'],
             'Landespflege':
                ['Landespflege','Landschaftsökologe',],   
             'Landwirt/in':
                ['Landwirt','Landwirtin','Landwirtschaftlicher Meister','Bauer','Landwirtschaftsmeister',
                 'Landwirt','Landwirtschaftsmeister','Mitarbeiterin im landw. Familienunternehmen'],
             'Lebensmittelkonservierer/in':
                ['Lebensmittelkonserviererin','Lebensmittelkonservierer'],
             'Agentur für Arbeit, leitende Position':
                ['Leiter eines Arbeitsamtes','Vorsitzende der Geschäftsführung der Agentur für Arbeit Stendal'],
             'Leitender Angestellter':
                ['Leitender Angestellter','Leitende Angestellte im Familienbetrieb','Referatsleiter'],
             'Literatur- und Kunsthistorikerin':
                ['Literatur- und Kunsthistorikerin','Literaturwissenschaftlerin M. A.','Literaturwissenschaftlerin'],
             'Leitender Angestellte/r':['Leitender Angestellter','Leitender Angestellter'],
             'Lokomotivführer':['Lokomotivführer'],
             'Marketing- und Kommunikationsmanagerin':
                ['Marketing- und Kommunikationsmanagerin','Marketingfachmann','Diplom Marketing Fachwirt (BAW)'],
             'Maschinen- und Anlagenmonteur/in':['Maschinen- und Anlagenmonteur','Maschinenbauer','Staatlich geprüfter Techniker für Maschinenbau'],
    
             'Mathematiker/in':['Mathematiker','Mathematikerin','Diplom-Mathematiker',
                'Diplom-Mathematikerin','Studium der  Mathematik'],
             'Mediengestalterin':['Mediengestalterin'],
             'Medienwissenschaftlerin':['Medienwissenschaftlerin','Medienwissenschaft und Geschichte'],
             'Metzgermeister/in':['Metzgermeister'],
             'Migrantenbeauftragte/r':['Migrantenbeauftragte a.D.'],  
             'Ministerialdirigent/in':['Ministerialdirigentin'],
             'Ministerialrat a. D.':['Ministerialrat a. D.'],
             'Müllermeister/in':['Müllermeister'],
             'Unbekannt':['Münster'],
            'Diplom-Umweltwissenschaftler/in':['Diplom-Umweltwissenschaftlerin',],
             'Neueren Geschichte und Soziologie (M.A.)':['Neueren Geschichte und Soziologie (M.A.)'],
             'Notar/in':['Notar'],
             'Oberregierungsrat/rätin':['Oberregierungsrat'],
             'Bundeswehr':['Oberstleutnant a.D.','Oberst a.D.'],
             'Öffentliches Recht':['Öffentliches Recht'],
             'Ökonom/Ökonomierat':['Ökonom','Ökonomin','Ökonomierat','promovierter und habilitierter Volkswirt','Wirtschaftswissenschaftler','Diplomfinanzökonomin',
                'Diplomingenieurökonom'],
             'Organisationsberater':['Organisationsberater','Selbstständiger Wirtschaftsmediator','selbständiger Wirtschaftsberater'],
             'Personalmanagement':['Personalberaterin','Personalmanagementökonomin'],
             'Pfarrer':['Pfarrer'],
             'Pharmazeutisch-kaufmännische Assistentin':['Pharmazeutisch-kaufmännische Assistentin'],
             'Philologin':['Philologin'],
             'Philosophie und Staatsrecht':['Philosophie und Staatsrecht'],
             'Physiker/in':['Physik','Physiker','Physikerin','Diplom-Physiker',
                'Diplom-Physikerin'],
             'Physiotherapeut':['Physiotherapeut','Diplom-Sporttherapeut'],
             'Politikerin':['Politikerin','Politiker'],
             'Polizeibeamter':['Polizeibeamter','Polizeibeamtin','Polizeidirektor a.D.','Polizist','Polizeibeamter/Polizeihauptkommissar'],
             'PR-Senior-Beraterin':['PR-Senior-Beraterin'],
             'Professor für Nachhaltiges Management':['Professor für Nachhaltiges Management'],
            'Prokurist':['Prokurist'],
            'Property Manager':['Property Manager'],
            'Psycholgische Berater/in':['Psychologische Beraterin und Heilpraktikerin für Psychotherapie','Diplom-Psychologe',
                'Diplom-Psychologin'],
            'Regierungsamtsrätin':['Regierungsamtsrätin'],
            'Regionalmanagerin':['Regionalmanagerin'],
            'Risikomanagement':['Risikomanagement'],
            'Romanistik und Pädagogik':['Romanistik und Pädagogik'],
            'Schlosser/in':['Schlosser','Schlosserin'],
            'Landschaftsgartenbau/Forstwirtschaft':['Dipl.Ing. Landschaftsplanung','Diplom-Forstingenieur','Diplomforstingenieur (FH)'],
            'Selbstständigig tätig':
                ['selbständig','Selbständiger Generalvertreter'],
            'Slawist/in':['Slawistin','Slawist'],
            'Sozialarbeiterin':['Sozialarbeiterin','Sozialpädagoge'],
            'Sozialwissenschaftlicher Hintergrund':
                     ['Diplomwirtschaftspädagoge','Diplom-Sozialwirt','Sozialwissenschaftler',
                                   'Sozialwissenschaftlerin','Soziolgie',
                                   'Soziologie und der deutschen Volkskunde','Soziologin','Studium der Geschichte',
                                   'Medienwissenschaft und Geschichte','Gesellschaftswissenschaftler','Diplom-Sozialwissenschaftler',
                                   'Diplom-Soziologe','Diplom-Soziologin','Geschichte'],
            'sozialpolitischer Vorstand':['sozialpolitischer Vorstand'],
            'Sprachwissenschaftler/in':['Sprachwissenschaftlerin und Diakonin','Sprachwissenschaftlerin'],
            'Steuerberater/in':['Steuerberater','Steuerberaterin'],
            'Städtische Verwaltung':['Städtischer Leitender Verwaltungsdirektor a. D.'],
            'Mitarbeiter Abgeordnetenbüro':
                     ['Student / Mitarbeiter einer Europaabgeordneten'],
            'Politikwissenschatflicher Hintergrund':
                     ['Hochschulstudium Politikwissenschaften','Studium der Politik- und Rechtswissenschaften','Abschluss in Politikwissenschaft','Studium der Politik','Studium der Politikwissenschaft',
                      'Studium der Politikwissenschaften und Öffentliches Recht','Studium der Politikwissenschaften','Studium der Politischen Wissenschaft mit den Nebenfächern Soziologie und Geschichte',
                      'Studium der Politischen Wissenschaft','Studium der Politischen Wissenschaften und Anglistik','Studium des Politikwissenschaften (Hauptfach)','Politikwissenschaft und Pädagogik auf Lehramt','Politikwissenschaft und Soziologie','Politikwissenschaftler (M.A.)',
                 'Politikwissenschaftler','Politikwissenschaftlerin (Dr. rer.pol.)','Politikwissenschaftlerin','Politologe','Politologie und Philosophie','Dipl.-Politologin','Diplom-Politikwissenschaftlerin',
                'Diplom-Politologe','Diplom-Politologin','Diplompolitologe','Master of International Public Policy'],
            'Sprachwissenschaftliches Studium':['Studium der Anglistik','Studium der Germanistik'],
            'Naturwissenschaftliches Studium':
                     ['Studium der Tiermedizin','Studium der Mathematik und Wirtschaftswissenschaften',
                      'Studium der Mathematik','Studium zum Maschinenbautechniker und Wirtschaftsingenieur',
                      'Diplom-Geologin','Diplom-Geograph','Diplom-Geographin'],
            'Studienverwaltung':
                     ['Studiendirektor am Berufskolleg','Studienrätin'],
            'Studium der Theologie':['Studium der Theologie'],
            'Techniker':
                     ['Techniker','Technischer Angestellter Qualitätssicherung','Technischer Angestellter','Technischer Oberamtsrat'],
            'Tierarzt/ärztin':
                     ['Tierarzt','Tierärztin','Veterinärmedizinerin'],
            'Theologe':
                     ['Theologe'],
            'Touristikfachwirt':
                     ['Touristikfachwirt'],
            'Universität/Hochschulsprofessor/in':
                     ['Universitätsprofessor','Universitätsprofessorin','Hochschulprofessor FHÖV, Münster','Universitätsprofessor a. D.','Hochschulprofessor FHÖV'],
            'Unternehmensberaterin':
                     ['Selbständiger Rechtsdienstleister und Wirtschaftsberater','Selbständiger Berater','Unternehmensberaterin','Unternehmensberater','Wirtschafts- und Unternehmensberater'],
            'Unternehmer':
                     ['Unternehmer','Unternehmerin','Selbstständiger Unternehmer'],
            'Veranstaltungskaufmann':
                     ['Veranstaltungskaufmann'],
            'Verkäufer/in':
                     ['Verkäuferin','Verkäufer'],
            'Verlagswesen':
                     ['Verlagsleiter','Verleger'],
            'Versicherungsfachmann/frau':
                     ['Versicherungsfachmann','Versicherungskaufmann'],
            'Tätigkeit in der Verwaltung':
                     ['Verwaltungs- und Betriebswirt','Verwaltungs-Betriebswirtin','Verwaltungsangestellter',
                      'Verwaltungsfachwirtin','Verwaltungsjurist','Verwaltungsjuristin','Verwaltungsleiter',
                      'Verwaltungsvollzugsbeamter','Diplom-Verwaltungswirt (FH)',
                      'Diplom-Verwaltungswirt','Diplom-Verwaltungswirtin',
                      'Diplom-Verwaltungswissenschaftlerin'],
            'Zahntechniker/in':
                     ['Zahntechniker'],
            'Werkzeugmacher/in':
                     ['Werkzeugmacher'],
            'Winzer':['Winzer','Winzer / Dipl.-Betriebswirt (FH)'],
            'Wissenschaftliche/r Mitarbeiter/in':
                     ['Wissenschaftlicher Mitarbeiter','Wissenschaftliche Mitarbeiterin',' wissenschaftliche Mitarbeiterin'],
            'Wirtschaftsprüfer/in':['Wirtschaftsprüfer','Wirtschaftsprüferin']
                                   }

# %%
#Categories braod
profession_broad = {'Agraringenieur*in / Landwirt*in':['Agraringenieur/in','Landwirt/in','Landespflege','Landschaftsgartenbau/Forstwirtschaft','Hochschulagraringenieur/in'],
                    'Ingenieur*in':['Bauingenieur/in','Ingenieur/in'],
                
                    'Betriebswirt*in / Kaufmänische Tätigkeit / Handel':
                    ['Betriebswirt/in', 'Buchhändler/in', 'Immobilienmakler/in','Pharmazeutisch-kaufmännische Assistentin','Industriekauffrau/mann','Handelsfachwirt/in','Einzelhandelskauffrau','Touristikfachwirt','Betriebswirtin',
                     'Groß- und Außenhandelskaufmann','Bürokaufmann/kauffrau','Veranstaltungskaufmann','Kauffrau/mann',
                     
                    ],
                    'Journalismus / Verlagswesen' :['Journalist/in', 'Verlagswesen','Autor/in'],
                    'Ökonom*in / Volkswirt*in' :['Volkswirt/in','Ökonom/Ökonomierat'],
                    'Sozialpädagoge*in / Sozialarbeiter*in':['Sozialarbeiterin','Sozialpädagoge/in','Erzieher','Kinderpflegerin'],
                    'Sprachwissenschaftlicher/Kommunikationswissenschaftlicher Hintergrund':['Philologin','Sprachwissenschaftliches Studium','Klassischer Philologe','Sprachwissenschaftler/in','Slawist/in','Romanistik und Pädagogik','Kommunikationswissenschaftler/in','Sprachwissenschaftler/in',],
                    'Handwerkschaftliche Berufe':
                    ['Baustofftechnologe/in','Architekt/in','Lokomotivführer','Bergmann','Bergmechaniker/in','Werkzeugmacher/in','Zahntechniker/in','Schlosser/in','Winzer',
                     'Bauzeichner/in', 'Baufacharbeiter','Maschinen- und Anlagenmonteur/in', 
                     'Baustofftechnologin','Damenschneidermeisterin','Industriemechaniker',
                     'Kfz-Mechaniker','Lebensmittelkonservierer/in','Techniker','Edelsteingutachter/in','Eisenbahnfacharbeiterin',
                                             'Elektrohandwerksmeister','Elektrohauer/in','Elektroinstallateur/in',
                                             'Funkmechaniker/in','Glasermeister/in','Goldschmied/in'],
                    'Medien- und Organisationsberatung':['Unternehmensberaterin','Mediengestalterin','Medienwissenschaftlerin','Organisationsberater','Bildungsberater','PR-Senior-Beraterin','Marketing- und Kommunikationsmanagerin',],
                    'Wissenschaft & Forschung':['Historiker/in','Professor für Nachhaltiges Management','Dozent/in','Wissenschaftliche/r Mitarbeiter/in','Universität/Hochschulsprofessor/in'],
                    'Beamte*r / Tätigkeit in der Verwaltung':['Bürgermeister/in','Verwaltungswirt/in','Studienverwaltung','Städtische Verwaltung','Tätigkeit in der Verwaltung','Beamte/r','Agentur für Arbeit, leitende Position','Agentur für Arbeit',' leitende Position',
                                                              'Büroleitung','Fremdsprachensekretär/in',
                                                              'Migrantenbeauftragte/r', 'Ministerialdirigent/in',
                                                              'Ministerialrat a. D.', 'Mitarbeiter Abgeordnetenbüro','Oberregierungsrat/rätin','Parlamentarische Referent/in'],
                    'Religionswissenschaftlicher Hintergrund':['Islamwissenschaftler/in','Diakon/in','Pfarrer','Studium der Theologie','Theologe'],
                    'Finanz-/Versicherungswesen':['Wirtschaftsprüfer/in','Bankfachwirt/In','Finanzwirt/in','Steuerberater/in','Versicherungsfachmann/frau','Notar/in'],
                    'Kulturelle und künstlerische Tätigkeiten':['Dramaturge/in','Kulturreferent/in','Literatur- und Kunsthistorikerin'],
                    'Medizinische/Psychologische Tätigkeit':['Apotheker/in','Physiotherapeut','Ärzt/in',
                                              'Tierarzt/ärztin', 'Examinierte Gesundheits- und Krankenpflegerin',
                                              'Kieferorthopäde/in','Krankenschwester/Krankenpfleger','Psycholgische Berater/in'],
                    'Lebensmittelbranche':['Konditor/in','Bäcker/in','Ernährungswissenschaftler/in',
                                           'Diplom-Umweltwissenschaftler/in','Kulturwissenschaftler/in','Metzgermeister/in'],
                    'Polizei & Bundeswehr':['Polizeibeamter','Kriminalbeamte/r','Soldat'],
                    'Management Tätigkeiten':
                    ['Personalmanagement','Personalfachkaufmann','Generalsekretär','Gesellschafter/in','Leitender Angestellter','Leitender Angestellte/r','Geschäftsführer/in','Projektmanager/in','Prokurist','Property Manager','Regionalmanagerin','Personalmanagement'],
                    'Sonstige Tätigkeiten':['Unternehmer','Selbstständigig tätig','selbständig','Angestellte/r','Außendienstmitarbeiter/in','Hausfrau/mann', 'Hauswirtschaftsleiterin (Hwl)'],
                    'Naturwissenschaftlicher Hintergrund': ['Naturwissenschaftliches Studium','Biologe/in', 'Chemiker/in','Physiker/in','Mathematiker/in'],
                    'Politikwissenschatflicher Hintergrund':['Politikwissenschatflicher Hintergrund','Politikberater/in'],
                    'Politisches Amt / Minister*in':['Bundesminister/in','Politikerin']
                    }
